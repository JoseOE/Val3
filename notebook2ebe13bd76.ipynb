# %%
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
datos = [26.67 , 16.67, 10, 26.67, 13.33, 6.66]
marcas_texto = ["Pumas", "CU CU PUMAS" , "Santos", "América", "Toluca", "Necaxa"]
separaciones = [0, 0, 0.2, 0, 0, 0]

plt.pie(datos, 
       explode = separaciones, 
       counterclock = False, 
       startangle = 90, 
       autopct = "%0.1f%%", 
       pctdistance = 0.8, 
       colors = ['#FF2D02', '#36FF00', '#00FFEC', '#E800FF', '#FFF300', '#0008FF'], 
       labels = marcas_texto)
plt.show()
